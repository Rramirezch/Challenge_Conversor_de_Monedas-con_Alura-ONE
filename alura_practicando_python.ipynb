# %% [markdown]
# <a href="https://colab.research.google.com/github/Rramirezch/Challenge_Conversor_de_Monedas-con_Alura-ONE/blob/main/alura_practicando_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# comenzando con python

# %%
print('Hola Mundo', 5)
# Out:
# Hola Mundo 5

# %%
print("Hola mundo")
producto_1 = "Chocolate"
producto_2 = "Helado"
producto_3 = "Celular"

print("Producto 1:", producto_1 )
# Out:
# Hola mundo
# Producto 1: Chocolate

# %%
#correccion de texto
texto = "eL caMino  es LargO  "
print(texto.capitalize())
print(texto.upper())
print(texto.lower())
print(texto.swapcase())
print(texto.strip())
print(texto.replace("  ", " "))
# Out:
# El camino  es largo
# EL CAMINO  ES LARGO
# el camino  es largo
# El CAmINO  ES lARGo
# eL caMino  es LargO
# eL caMino es LargO

# %%
nombre = input("Ingrese su nombre: ")
print("Hola", nombre)
edad = int(input("Ingrese su edad: "))
print("La edad de:",nombre, "es", edad)
edad =int(edad)
print("edad :", type(edad))
print(f"su nombre es {nombre} y su edad es {edad}")
# Out:
# Ingrese su nombre: rodrigo
# Hola rodrigo
# Ingrese su edad: 60
# La edad de: rodrigo es 60
# edad : <class 'int'>
# su nombre es rodrigo y su edad es 60

# %%
#Condicionales
if edad >= 18:
    print("Es mayor de edad")
else:
    print("Es menor de edad")
# Out:
# Es mayor de edad

# %%
alquiler_deposito = 5000
comsumo_combustible = 2000
mantenimiento_vehiculo = 1500
rutas = 10
costo_promedio_por_ruta =(alquiler_deposito + comsumo_combustible + mantenimiento_vehiculo) / rutas
print("El costo promedio por ruta es:", costo_promedio_por_ruta)
# Out:
# El costo promedio por ruta es: 850.0

# %%
#python segunda parte
import os
#creo variable de entorno

from google.colab import userdata
os.environ['APYKEY-PYTHON'] = userdata.get('APYKEY-PYTHON')

# %%
from google import genai
client = genai.Client(api_key=os.environ['APYKEY-PYTHON'])

# %%
respuesta = client.models.generate_content(model="gemini-2.5-flash", contents="Que es la IA")

# %%
#bucles

print(*******)

# %%
#while
n = 1
while n <= 10:
  print("*")
  n=n+1
print("Salimos del while")
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# Salimos del while

# %%
#crear chatbot
chat = client.chats.create(model="gemini-2.5-flash")

# %%
respuesta1 = chat.send_message("Cuando se lanzó chat-gpt")
print(respuesta1.text)
# Out:
# ChatGPT fue lanzado por OpenAI el **30 de noviembre de 2022**.
#
# Fue lanzado inicialmente como una vista previa de investigación y rápidamente ganó una inmensa popularidad debido a su capacidad para generar texto coherente y similar al humano, y mantener conversaciones sofisticadas.

# %%
print(respuesta.text)
# Out:
# La **Inteligencia Artificial (IA)**, en su esencia, es la capacidad de una máquina o un programa de computadora para **simular la inteligencia humana**. Esto implica que puede realizar tareas que normalmente requerirían pensamiento, aprendizaje, resolución de problemas, percepción y toma de decisiones por parte de un ser humano.
#
# En términos más sencillos, es cuando le enseñamos a las computadoras a "pensar" o "actuar" de manera inteligente, como lo haríamos nosotros, pero a menudo mucho más rápido y con grandes volúmenes de datos.
#
# **¿Qué hace la IA?**
#
# La IA abarca una serie de capacidades, incluyendo:
#
# 1.  **Aprendizaje (Machine Learning):** Es la rama más importante de la IA. Permite a los sistemas aprender de los datos sin ser programados explícitamente. Es decir, en lugar de decirle "si pasa A, haz B", el sistema analiza miles de ejemplos de A y B, y aprende la relación por sí mismo.
# ...

# %%
#el chat es para que conserve en memoria las consultas que hemos realizado
chat.get_history() #para verificar el historial de las respuesta o conversaciones

# %%
prompt = input("Ingrese una pregunta")
while prompt != "fin"
respuesta2 = chat.send_message(prompt)
print(respuesta2.text)
prompt = input("Ingrese una pregunta o fin para terminar")

# %%
#listas
nombres = ["Juan", "Pedro", "Maria", "Ana"]

# %%
promedios =[4.5, 7.8, 8.5, 9.6]
n = 0
while n < 4:
  promedios[n]=promedios[n]+1

  if promedios[n] > 10:
    promedios[n]=10
  n=n+1
print("promedios =", promedios)
print("elementos de promedios =:", len(promedios))
# Out:
# promedios = [5.5, 8.8, 9.5, 10]
# elementos de promedios =: 4

# %%
nombres =["juan rojas", "pedro perez", "juana rodriguez"]

nombres.extend(['rodrigo ramirez'])
nombres.append('ana perez')

print(nombres)
nombres.remove("juan rojas")

print(nombres)
nombres.pop(1)
print(nombres)
# Out:
# ['juan rojas', 'pedro perez', 'juana rodriguez', 'rodrigo ramirez', 'ana perez']
# ['pedro perez', 'juana rodriguez', 'rodrigo ramirez', 'ana perez']
# ['pedro perez', 'rodrigo ramirez', 'ana perez']

# %%
#Diccionarios
#estudiantes = clave, valor
nombre = ["pedro rojas", "juan perez", "roberto matinez", "rodrigo ramirez"]
promedios=[5.4, 6.7, 8.0, 9.0]

estudiantes={
    "pedro rojas": 5.4,
    "juan perez": 6.7,
    "roberto matinez": 8.0,
    "rodrigo ramirez": 9.0
}

print(nombres)
print(promedios)
print(estudiantes)
print(estudiantes['juan perez'])
print(estudiantes.get("juan perez"))
estudiantes.pop("juan perez")
estudiantes
print(estudiantes.keys())
print(estudiantes.values())
print(estudiantes.items())
# Out:
# ['pedro perez', 'rodrigo ramirez', 'ana perez']
# [5.4, 6.7, 8.0, 9.0]
# {'pedro rojas': 5.4, 'juan perez': 6.7, 'roberto matinez': 8.0, 'rodrigo ramirez': 9.0}
# 6.7
# 6.7
# dict_keys(['pedro rojas', 'roberto matinez', 'rodrigo ramirez'])
# dict_values([5.4, 8.0, 9.0])
# dict_items([('pedro rojas', 5.4), ('roberto matinez', 8.0), ('rodrigo ramirez', 9.0)])

# %%
estudiante1 ={
    "nombre": "Pedro Torres",
    "edad": 23
}
estudiante2 ={
    "nombre": "Roberto Rodriguez",
    "edad": 20
}

lista_de_estudiantes=[estudiante1, estudiante2]
print(lista_de_estudiantes)
lista_de_estudiantes[1]["nombre"], lista_de_estudiantes[0]["edad"]
# Out:
# [{'nombre': 'Pedro Torres', 'edad': 23}, {'nombre': 'Roberto Rodriguez', 'edad': 20}]
# ('Roberto Rodriguez', 23)
